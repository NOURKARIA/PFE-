# %%
import json

# El JSON data eli 3atytheli m3a el intents
raw_json_data = [
    {"step": "When I click the login button", "intent": "ACTION_CLICK", "target": "login button", "value": None},
    {"step": "And I enter 'john.doe' in the username field", "intent": "ACTION_TYPE", "target": "username field", "value": "john.doe"},
    {"step": "Given I navigate to the home page", "intent": "NAVIGATION", "target": "home page", "value": None},
    {"step": "Then I verify the dashboard is visible", "intent": "VERIFICATION", "target": "dashboard", "value": None},
    {"step": "When I type 'password123' into the password input", "intent": "ACTION_TYPE", "target": "password input", "value": "password123"},
    {"step": "And I tap on the settings icon", "intent": "ACTION_CLICK", "target": "settings icon", "value": None},
    {"step": "Then the success message should appear", "intent": "VERIFICATION", "target": "success message", "value": None},
    {"step": "Given the user goes to the profile URL", "intent": "NAVIGATION", "target": "profile URL", "value": None},
    {"step": "When I press the submit form button", "intent": "ACTION_CLICK", "target": "submit form button", "value": None},
    {"step": "And I input 'test@email.com' into the email textbox", "intent": "ACTION_TYPE", "target": "email textbox", "value": "test@email.com"},
    {"step": "Then I see the error banner", "intent": "VERIFICATION", "target": "error banner", "value": None},
    {"step": "When I click the 'forgot password' link", "intent": "ACTION_CLICK", "target": "'forgot password' link", "value": None},
    {"step": "And I enter '9900' in the zip code field", "intent": "ACTION_TYPE", "target": "zip code field", "value": "9900"},
    {"step": "Given I open the checkout page", "intent": "NAVIGATION", "target": "checkout page", "value": None},
    {"step": "Then the shopping cart should be empty", "intent": "VERIFICATION", "target": "shopping cart", "value": None},
    {"step": "When I select the country dropdown", "intent": "ACTION_CLICK", "target": "country dropdown", "value": None},
    {"step": "And I type 'Paris' into the search bar", "intent": "ACTION_TYPE", "target": "search bar", "value": "Paris"},
    {"step": "Given I visit the admin dashboard", "intent": "NAVIGATION", "target": "admin dashboard", "value": None},
    {"step": "Then I confirm the user table is loaded", "intent": "VERIFICATION", "target": "user table", "value": None},
    {"step": "When I click on the delete icon", "intent": "ACTION_CLICK", "target": "delete icon", "value": None},
    {"step": "And I provide '1234-5678' to the credit card input", "intent": "ACTION_TYPE", "target": "credit card input", "value": "1234-5678"},
    {"step": "Given I load the payment screen", "intent": "NAVIGATION", "target": "payment screen", "value": None},
    {"step": "Then I ensure the confirmation modal pops up", "intent": "VERIFICATION", "target": "confirmation modal", "value": None},
    {"step": "When I tap the cancel button", "intent": "ACTION_CLICK", "target": "cancel button", "value": None},
    {"step": "And I write 'Hello World' in the comments area", "intent": "ACTION_TYPE", "target": "comments area", "value": "Hello World"},
    {"step": "Then the new comment should be displayed", "intent": "VERIFICATION", "target": "new comment", "value": None},
    {"step": "Given I am on the login portal", "intent": "NAVIGATION", "target": "login portal", "value": None},
    {"step": "When I click 'Accept Cookies'", "intent": "ACTION_CLICK", "target": "'Accept Cookies'", "value": None},
    {"step": "And I fill the age field with '25'", "intent": "ACTION_TYPE", "target": "age field", "value": "25"},
    {"step": "Then I check if the header logo is present", "intent": "VERIFICATION", "target": "header logo", "value": None},
    {"step": "When I push the toggle switch", "intent": "ACTION_CLICK", "target": "toggle switch", "value": None},
    {"step": "And I insert '500' in the amount box", "intent": "ACTION_TYPE", "target": "amount box", "value": "500"},
    {"step": "Then the total price must be visible", "intent": "VERIFICATION", "target": "total price", "value": None},
    {"step": "Given the user redirects to the settings page", "intent": "NAVIGATION", "target": "settings page", "value": None},
    {"step": "When I click the logout link", "intent": "ACTION_CLICK", "target": "logout link", "value": None},
    {"step": "And I set the phone number to '555-0101'", "intent": "ACTION_TYPE", "target": "phone number", "value": "555-0101"},
    {"step": "Then the logout success toast should show up", "intent": "VERIFICATION", "target": "logout success toast", "value": None},
    {"step": "When I hit the register button", "intent": "ACTION_CLICK", "target": "register button", "value": None},
    {"step": "And I input 'John' as the first name", "intent": "ACTION_TYPE", "target": "first name", "value": "John"},
    {"step": "Given I navigate back to the product list", "intent": "NAVIGATION", "target": "product list", "value": None},
    {"step": "Then I verify the item count is correct", "intent": "VERIFICATION", "target": "item count", "value": None},
    {"step": "When I click 'Next' on the pagination", "intent": "ACTION_CLICK", "target": "'Next' on the pagination", "value": None},
    {"step": "And I type 'Apples' in the grocery search", "intent": "ACTION_TYPE", "target": "grocery search", "value": "Apples"},
    {"step": "Then the apple image should render", "intent": "VERIFICATION", "target": "apple image", "value": None},
    {"step": "Given I route to the map screen", "intent": "NAVIGATION", "target": "map screen", "value": None},
    {"step": "When I select the zoom in button", "intent": "ACTION_CLICK", "target": "zoom in button", "value": None},
    {"step": "And I enter '10' into the quantity input", "intent": "ACTION_TYPE", "target": "quantity input", "value": "10"},
    {"step": "Then the map pin must appear", "intent": "VERIFICATION", "target": "map pin", "value": None},
    {"step": "When I click the 'Agree' checkbox", "intent": "ACTION_CLICK", "target": "'Agree' checkbox", "value": None},
    {"step": "And I type 'Discount2026' in the promo code field", "intent": "ACTION_TYPE", "target": "promo code field", "value": "Discount2026"}
]

train_data = []

for item in raw_json_data:
    text = item["step"]
    entities = []

    # 1. Check for VALUE (e.g., 'john.doe')
    if item["value"]:
        val = str(item["value"])
        start_v = text.find(val)
        if start_v != -1:
            entities.append((start_v, start_v + len(val), "VALUE"))

    # 2. Check for TARGET (e.g., 'login button')
    if item["target"]:
        target = item["target"]
        start_t = text.find(target)
        if start_t != -1:
            entities.append((start_t, start_t + len(target), "TARGET"))

    train_data.append((text, {"entities": entities}))

# Output el list l-kbira
for example in train_data:
    print(f"{example},")
# Out:
# ('When I click the login button', {'entities': [(17, 29, 'TARGET')]}),
# ("And I enter 'john.doe' in the username field", {'entities': [(13, 21, 'VALUE'), (30, 44, 'TARGET')]}),
# ('Given I navigate to the home page', {'entities': [(24, 33, 'TARGET')]}),
# ('Then I verify the dashboard is visible', {'entities': [(18, 27, 'TARGET')]}),
# ("When I type 'password123' into the password input", {'entities': [(13, 24, 'VALUE'), (35, 49, 'TARGET')]}),
# ('And I tap on the settings icon', {'entities': [(17, 30, 'TARGET')]}),
# ('Then the success message should appear', {'entities': [(9, 24, 'TARGET')]}),
# ('Given the user goes to the profile URL', {'entities': [(27, 38, 'TARGET')]}),
# ('When I press the submit form button', {'entities': [(17, 35, 'TARGET')]}),
# ("And I input 'test@email.com' into the email textbox", {'entities': [(13, 27, 'VALUE'), (38, 51, 'TARGET')]}),
# ('Then I see the error banner', {'entities': [(15, 27, 'TARGET')]}),
# ...

# %%
import torch
from transformers import DistilBertTokenizerFast, DistilBertForTokenClassification, Trainer, TrainingArguments
import numpy as np

# 1. Labels mte3na (O = Outside, B- = Beginning of entity)
label_list = ["O", "B-TARGET", "I-TARGET", "B-VALUE", "I-VALUE"]
label_map = {label: i for i, label in enumerate(label_list)}

# 2. Tokenizer (Fast version is needed for alignment)
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')

# 3. Model Architecture
model = DistilBertForTokenClassification.from_pretrained('distilbert-base-uncased', num_labels=len(label_list))

# --- Hna lezem t-7ott el data mte3ek m-formatted lel NER ---
# (Bech n-supposiw 3andek 'train_texts' w 'train_tags')

def tokenize_and_align_labels(texts, tags):
    tokenized_inputs = tokenizer(texts, truncation=True, padding=True, is_split_into_words=True)
    labels = []
    # Logic bech n-aligniw kol kelma m3a el label mte3ha f'west el model
    # ... (skipping long logic for brevity, it's standard NER boilerplate)
    return tokenized_inputs

# 4. Training Arguments
training_args = TrainingArguments(
    output_dir='./ner_results',
    num_train_epochs=30,
    per_device_train_batch_size=8,
    save_steps=100,
)

# 5. Save the .pt weights
# Ba3d el trainer.train()
torch.save(model.state_dict(), 'entity_extractor.pt')
print("✅ Done! You now have a second LLM file: entity_extractor.pt")
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForTokenClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# classifier.bias         | MISSING    |
# classifier.weight       | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ✅ Done! You now have a second LLM file: entity_extractor.pt
